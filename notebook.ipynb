# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-изучение-общей-информации" data-toc-modified-id="Загрузка-данных-и-изучение-общей-информации-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и изучение общей информации</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Переименуем-столбцы" data-toc-modified-id="Переименуем-столбцы-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Переименуем столбцы</a></span></li><li><span><a href="#Проверим-пропущенные-значения" data-toc-modified-id="Проверим-пропущенные-значения-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверим пропущенные значения</a></span></li><li><span><a href="#Проверим-наличие-дубликатов" data-toc-modified-id="Проверим-наличие-дубликатов-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Проверим наличие дубликатов</a></span></li><li><span><a href="#Изменим-тип-данных-в-столбцах-score-и-age-на-int" data-toc-modified-id="Изменим-тип-данных-в-столбцах-score-и-age-на-int-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Изменим тип данных в столбцах score и age на int</a></span></li><li><span><a href="#Проверим-на-уникальность-значения-столбцов-city-и-gender" data-toc-modified-id="Проверим-на-уникальность-значения-столбцов-city-и-gender-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Проверим на уникальность значения столбцов city и gender</a></span></li><li><span><a href="#Добавим-столбцы-с-наименованиями-городов-и-по-гендерному-признаку" data-toc-modified-id="Добавим-столбцы-с-наименованиями-городов-и-по-гендерному-признаку-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Добавим столбцы с наименованиями городов и по гендерному признаку</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ" data-toc-modified-id="Исследовательский-анализ-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ</a></span><ul class="toc-item"><li><span><a href="#Портрет-клиента" data-toc-modified-id="Портрет-клиента-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Портрет клиента</a></span></li><li><span><a href="#Анализ-отточных-клиентов.-Распределения" data-toc-modified-id="Анализ-отточных-клиентов.-Распределения-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ отточных клиентов. Распределения</a></span></li><li><span><a href="#Анализ-оттока-клиентов.-Доли-отточных-клиентов" data-toc-modified-id="Анализ-оттока-клиентов.-Доли-отточных-клиентов-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Анализ оттока клиентов. Доли отточных клиентов</a></span></li><li><span><a href="#Корреляционный-анализ" data-toc-modified-id="Корреляционный-анализ-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Корреляционный анализ</a></span></li></ul></li><li><span><a href="#Статистический-анализ" data-toc-modified-id="Статистический-анализ-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Статистический анализ</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-различия-дохода-между-теми-клиентами,-которые-ушли-и-теми,-которые-остались" data-toc-modified-id="Гипотеза-различия-дохода-между-теми-клиентами,-которые-ушли-и-теми,-которые-остались-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Гипотеза различия дохода между теми клиентами, которые ушли и теми, которые остались</a></span></li><li><span><a href="#Гипотеза-различия-количества-банковских-продуктов-между-теми-клиентами,-которые-ушли-и-теми,-которые-остались" data-toc-modified-id="Гипотеза-различия-количества-банковских-продуктов-между-теми-клиентами,-которые-ушли-и-теми,-которые-остались-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Гипотеза различия количества банковских продуктов между теми клиентами, которые ушли и теми, которые остались</a></span></li><li><span><a href="#Гипотеза-различия-количества-баллов-собственности-между-теми-клиентами,-которые-ушли-и-теми,-которые-остались" data-toc-modified-id="Гипотеза-различия-количества-баллов-собственности-между-теми-клиентами,-которые-ушли-и-теми,-которые-остались-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Гипотеза различия количества баллов собственности между теми клиентами, которые ушли и теми, которые остались</a></span></li></ul></li><li><span><a href="#Сегментация" data-toc-modified-id="Сегментация-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Сегментация</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <b>Привет, Любовь!👋
#
# Это твой тимлид - Эльвира Нургалиева. Предлагаю общаться на «ты», но если это не удобно - дай мне знать, и мы перейдем на «вы».
#
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
#
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊<a class="tocSkip"> </h2>
#
# Такими комментариями я буду помечать отлично проделаную работу😉
# </div>
#
# <div class="alert alert-warning">
# <h2> Комментарий тимлида 🤓<a class="tocSkip"> </h2>
#
# В таких комментариях я постараюсь подсказать тебе более элегантное или легкое решение, некоторые хитрости и фишки. Части проекта, помеченные такими комментариями, можно не исправлять, но рекомендую обратить на них внимание.</div>
#
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
#
# В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Если ты видишь такой комментарий, значит здесть есть недочет, который следует исправить.
# </div>
#
# Ты также можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. Это нужно, чтобы не создавалась путаница🙃
#
# `<div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>`
#
# Чтобы сделать подобный блок, кликни здесь дважды и скопируй всю предыдущую строку ;)
#
# Пожалуйста, не удаляй и не перемещай мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.</div></b>

# %% [markdown]
# # Анализ оттока клиентов банка.

# %% [markdown]
# Заказчик — отдел маркетинга банка «Метанпромбанк».
# **Задача проекта:**  выявить характеристики отточных клиентов, выделить сегменты отточных клиентов и дать примеры мероприятий, которые можно провести, чтобы вернуть клиентов в банк или удержать сомневающихся от оттока.

# %% [markdown]
# **Основные этапы проведения анализа**
#
#     1. Загрузка данных и изучение общей информации
#     2. Подготовка данных к анализу
#         2.1 Переименуем столбцы
#         2.2 Приведем значения отдельных столбцов к соответствующему типу данных
#         2.3 Наличие пропущенных значений. Проверим, есть ли зависимость пропущенных значений в столбце balance от признака наличия кредитной карты при условии, что клиент пользуется только одним продуктом
#         2.4 Проверим наличие явных и неявных дубликатов
#         2.5 Проверим на уникальность значения в столбцах city, gender
#         2.6 Добавим дополнительные столбцы с наименованиями городов (кодирование столбца city)
#         2.7 Добавим дополнительные столбцы с гендерными признаками (кодирование столбца gender)
#     3. Исследовательский анализ данных
#         3.1 сравнение портретов типичных клиентов (средние и медианы) по:
#         полу, возрасту, городу, баллам кредитного скоринга, оценке собственности клиента, балансу на счёте, количество продуктов, которыми пользуется клиент, наличию кредитной карты, активности клиента за последнее время, оценочной заработной плате клиента
#         3.2 определим интервалы значений характеристик, которые связаны с повышенным оттоком,
#         3.3 определим доли отточных клиентов по основным признакам
#         3.4 корреляционный анализ
#     4. Статистический анализ.
#
#         4.1 Проверим гипотезу различия дохода между теми клиентами, которые ушли и теми, которые остались.
#         4.2 Проверим статистическую гипотезу относительно представленных данных, которая поможет внести ясность в исследование
#     5. Сформируем сегменты, объединив признаки отточности, отберите из них лучшие и дайте по ним рекомендации

# %% [markdown]
# Ссылка на презентацию: https://disk.yandex.ru/i/d-92MApORQtLJQ

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊<a class="tocSkip"> </h2>
#
# Отлично, что есть введение к проекту)

# %% [markdown]
# ## Загрузка данных и изучение общей информации

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import plotly.express as px
import seaborn as sns
from statistics import mode
from scipy import stats as st
from scipy.stats import shapiro
from scipy.stats import kstest

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊<a class="tocSkip"> </h2>
#
# Необходимые библиотеки загружены)

# %%
try:
    df = pd.read_csv('bank_scrooge.csv')
except:
    df = pd.read_csv('https://code.s3.yandex.net/datasets/bank_scrooge.csv')

# %%
df.head()
# Out:
#    USERID  score       city gender   age  equity     balance  products  \
# 0  183012  850.0    Рыбинск      Ж  25.0       1    59214.82         2
# 1  146556  861.0    Рыбинск      Ж  37.0       5   850594.33         3
# 2  120722  892.0    Рыбинск      Ж  30.0       0         NaN         1
# 3  225363  866.0  Ярославль      Ж  51.0       5  1524746.26         2
# 4  157978  730.0  Ярославль      М  34.0       5      174.00         1
#
#    credit_card  last_activity  EST_SALARY  churn
# 0            0              1    75719.14      1
# 1            1              0    86621.77      0
# 2            1              1   107683.34      0
# 3            0              1   174423.53      1
# 4            1              0    67353.16      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   USERID         10000 non-null  int64
#  1   score          10000 non-null  float64
#  2   city           10000 non-null  object
#  3   gender         10000 non-null  object
#  4   age            9974 non-null   float64
#  5   equity         10000 non-null  int64
#  6   balance        7705 non-null   float64
#  7   products       10000 non-null  int64
#  8   credit_card    10000 non-null  int64
#  9   last_activity  10000 non-null  int64
#  10  EST_SALARY     10000 non-null  float64
#  11  churn          10000 non-null  int64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 937.6+ KB

# %%
# посмотрим min, max, среднее и тд.
df.describe().T
# Out:
#                  count           mean           std      min        25%  \
# USERID         10000.0  171814.712600  3.370824e+04  94561.0  142810.25
# score          10000.0     848.699400  6.544852e+01    642.0     802.00
# age             9974.0      42.734409  1.217997e+01     18.0      33.00
# equity         10000.0       2.627600  1.980836e+00      0.0       0.00
# balance         7705.0  827794.306510  1.980614e+06      0.0  295554.16
# products       10000.0       1.870100  7.926467e-01      0.0       1.00
# credit_card    10000.0       0.680400  4.663449e-01      0.0       0.00
# last_activity  10000.0       0.523500  4.994724e-01      0.0       0.00
# EST_SALARY     10000.0  147866.885544  1.393885e+05   2546.3   75251.90
# churn          10000.0       0.182000  3.858638e-01      0.0       0.00
#
#                       50%          75%           max
# USERID         172728.000  201261.7500  2.291450e+05
# score             853.000     900.0000  1.000000e+03
# ...

# %% [markdown]
# В нашем распоряжении данные о клиентах банка «Метанпром». Банк располагается в Ярославле и областных городах: Ростов Великий и Рыбинск. Необходимо изменить наименования столбцов USERID и EST_SALARY. Преобразуем тип данных в столбцах score и age на int. В датасете есть пропуски. Оценим долю пропусков, возможность их заполнения и примем решение, оставить пропуски или удалить.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Привет, Эльвира. Добавила вывод к 1 разделу</div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий тимлида 🤓<a class="tocSkip"> </h2>
#
# Сразу после получения информации о таблице, будет здорово сформулировать вывод: проверить типы данных, а также важно понять, что по пропущенным значениям.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊 v_2 <a class="tocSkip"> </h2>
#
# 👍

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Переименуем столбцы

# %%
df.rename(columns={'USERID': 'user_id', 'EST_SALARY': 'est_salary'}, inplace = True)

# %% [markdown]
# ### Проверим пропущенные значения

# %%
#df.isna().sum()

# %%
report = df.isna().sum().to_frame()
report = report.rename(columns = {0: 'missing_values'})
report['% of total'] = (report['missing_values'] / df.shape[0]).round(2)
report.sort_values(by = 'missing_values', ascending = False)
# Out:
#                missing_values  % of total
# balance                  2295        0.23
# age                        26        0.00
# user_id                     0        0.00
# score                       0        0.00
# city                        0        0.00
# gender                      0        0.00
# equity                      0        0.00
# products                    0        0.00
# credit_card                 0        0.00
# last_activity               0        0.00
# est_salary                  0        0.00
# churn                       0        0.00

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий тимлида 🤓<a class="tocSkip"> </h2>
#
# Удобнее смотреть на процент пропусков по колонкам, это можно сделать,  например, так:
#
# `data.isnull().sum()*100/len(data)`
#
# Более продвинутый вариант (кол-во пропусков + процент пропусков)
#
# `report = data.isna().sum().to_frame()
# report = report.rename(columns = {0: 'missing_values'})
# report['% of total'] = (report['missing_values'] / data.shape[0]).round(2)
# report.sort_values(by = 'missing_values', ascending = False)`
#
# Это полезное действие при подборе стратегии заполнения пропусков: обычно, если в данных кол-во пропусков превышает 10%, восполнение пропусков результатами выполнения стандартных операций типа расчета среднего/медианы по столбцу, может привести к искажению данных. Если мы сталкиваемся с такой ситуацией, то важно подумать и подобрать более сложную восполнения пропусков в данных.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Эльвира, спасибо за подсказки. Так намного информативнее выходит :)</div>

# %% [markdown]
# С учетом маленького количества пропусков в столбце age, удалим пропущенные значения

# %%
df = df.dropna(subset = ['age'])
#df = df.reset_index()

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий тимлида 🤓<a class="tocSkip"> </h2>
#
# Такое малое кол-во пропусков будет лучше удалить сразу)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Удалила пропуски в столбце age.</div>

# %%
#df['age'] = df['age'].fillna(0)
df.isna().sum()# проверим результат
# Out:
# user_id             0
# score               0
# city                0
# gender              0
# age                 0
# equity              0
# balance          2279
# products            0
# credit_card         0
# last_activity       0
# est_salary          0
# churn               0
# dtype: int64

# %%
#print(df['balance'].corr(df['products']))
#print(df['balance'].corr(df['credit_card']))
#print(df['balance'].corr(df['est_salary']))
#print(df['balance'].corr(df['churn']))

# %% [markdown]
# Чтобы установить связь пропусков в столбце balance с данными, добавим столбец, в котором будет отображаться 0 - если пропуска в балансе нет и 1 -  если пропуск есть.

# %%
df['missing_balance'] = np.where(df['balance'].isna(),1,0)
df.head()
# Out:
#    user_id  score       city gender   age  equity     balance  products  \
# 0   183012  850.0    Рыбинск      Ж  25.0       1    59214.82         2
# 1   146556  861.0    Рыбинск      Ж  37.0       5   850594.33         3
# 2   120722  892.0    Рыбинск      Ж  30.0       0         NaN         1
# 3   225363  866.0  Ярославль      Ж  51.0       5  1524746.26         2
# 4   157978  730.0  Ярославль      М  34.0       5      174.00         1
#
#    credit_card  last_activity  est_salary  churn  missing_balance
# 0            0              1    75719.14      1                0
# 1            1              0    86621.77      0                0
# 2            1              1   107683.34      0                1
# 3            0              1   174423.53      1                0
# 4            1              0    67353.16      1                0

# %%
df_corr_balance=df.corr()
df_corr_balance=df_corr_balance.drop(['user_id','balance'])
df_corr_balance
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df_corr_balance=df.corr()
#       2 df_corr_balance=df_corr_balance.drop(['user_id','balance'])
#       3 df_corr_balance
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️ v_2<a class="tocSkip"></h2>
# <s>
# Так как это выпускной проект, при падении кода проект будет возвращен без проверки в следующий раз.

# %%
sns.heatmap(df_corr_balance.loc[:,['missing_balance']].drop('missing_balance'), annot=True, cmap='vlag', center=0, fmt='.2%')    
plt.title('Корреляция пропусков в столбце balance') 
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
# <s>
# Такая корреляция не может установить связь пропусков в балансе с данными. Чтобы оценить связь с пропусками необходимо построить дополнительный столбец, который будет отображать есть пропуск в данных или нет (можно заполнить как 0 и 1). И тогда уже по новому столбцу мы сможем изучить корреляцию для выявления взаимосвязи. Корреляцию необходимо будет изучить по всем признакам, чтобы вывести только нужный столбец, чможешь использовать код с презентации на вводной встрече)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Эльвира, дополнила раздел корреляцией</div>

# %% [markdown]
# Пропущенные значения в столбце balance имеют слабую зависимость от оценочного дохода клиента. По другим характеристикам связь очень слабая или отрицательная(при увеличении одной переменной другая уменьшается). Средняя обратная зависимость наблюдается между наличием пропуска в балансе с количеством продуктов и высокая отрицательная корреляция - наличие пропуска с количеством баллов собственности.  Вероятно, наличие пропусков связано с тем, что данные клиенты не имеют депозитных, накопительных счетов или вкладов и пользуются другими продуктами и услугами банка: кредитные карты, страхование, банковские ячейки и др. Также возможны и технические сбои при выгрузке данных, например. Так как заполнить пропущенные значения не представляется возможным, пропуски оставляем.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊 v_2 <a class="tocSkip"> </h2>
#
# Отлично)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
# <s>
#   Нужно будет доработать и обновить вывод)

# %% [markdown]
# ### Проверим наличие дубликатов

# %%
print('Количество дубликатов в таблице:', df.duplicated().sum())
# Out:
# Количество дубликатов в таблице: 0

# %%
# проверим датафрейм на наличие неявных дубликатов
df.loc[df.duplicated(subset=['user_id'], keep=False)].sort_values('user_id')
# Out:
#       user_id  score       city gender   age  equity      balance  products  \
# 1893   116540  883.0    Рыбинск      Ж  55.0       1    362756.49         3
# 7694   116540  887.0  Ярославль      Ж  38.0       0          NaN         1
# 4866   117943  855.0    Рыбинск      Ж  32.0       6   1036832.93         4
# 7542   117943  880.0  Ярославль      Ж  40.0       0          NaN         1
# 5863   120258  908.0    Рыбинск      Ж  38.0       4   2213581.63         2
# ...       ...    ...        ...    ...   ...     ...          ...       ...
# 2302   220816  934.0    Рыбинск      Ж  74.0       5   1294285.39         3
# 2597   226719  990.0  Ярославль      М  37.0       4  14648692.14         2
# 4216   226719  903.0    Рыбинск      Ж  63.0       0          NaN         1
# 8205   227795  840.0    Рыбинск      М  34.0       2    350768.03         1
# 8497   227795  839.0  Ярославль      М  34.0       2    326593.14         2
#
# ...

# %% [markdown]
# Здесь мы видим, что клиенты с одинаковыми id встречаются в разных городах. Вероятно, присвоение идентификатора пользователя в разных филиалах банка происходит независимо. Оставляем.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊<a class="tocSkip"> </h2>
#
# Хорошо)

# %% [markdown]
# ### Изменим тип данных в столбцах score и age на int

# %%
df['score'] = df['score'].astype(int)
df['age'] = df['age'].astype(int)

# %% [markdown]
# ### Проверим на уникальность значения столбцов city и gender

# %%
df['city'].unique()
# Out:
# array(['Рыбинск', 'Ярославль', 'Ростов'], dtype=object)

# %%
df['gender'].unique()
# Out:
# array(['Ж', 'М'], dtype=object)

# %% [markdown]
# ### Добавим столбцы с наименованиями городов и по гендерному признаку

# %%
df['city_dummies'] = df['city']
df['gender_dummies'] = df['gender']
df = pd.get_dummies(df, columns=['city_dummies', 'gender_dummies'], prefix='', prefix_sep='', dtype=int)

# %%
df.head(10)
# Out:
#    user_id  score       city gender  age  equity     balance  products  \
# 0   183012    850    Рыбинск      Ж   25       1    59214.82         2
# 1   146556    861    Рыбинск      Ж   37       5   850594.33         3
# 2   120722    892    Рыбинск      Ж   30       0         NaN         1
# 3   225363    866  Ярославль      Ж   51       5  1524746.26         2
# 4   157978    730  Ярославль      М   34       5      174.00         1
# 5   202305    856    Рыбинск      М   56       4   863687.24         3
# 6   177259    807  Ярославль      Ж   39       3   405042.44         3
# 7   218868    825  Ярославль      Ж   38       4   458145.40         2
# 8   211686    923  Ярославль      М   54       5  1206337.87         2
# 9   133130    906  Ярославль      Ж   67       0         NaN         1
#
#    credit_card  last_activity  est_salary  churn  missing_balance  Ростов  \
# 0            0              1    75719.14      1                0       0
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊<a class="tocSkip"> </h2>
#
#  Кодирование проведено верно)

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий тимлида 🤓<a class="tocSkip"> </h2>
#
# Обрати внимание, что мы создаем два столбца с полом) А для анализа в целом будет достаточно и одного, можем использовать другой вариант кодирования или опустить лишний столбец, используя параметр `drop_first=True`)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9974 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_id          9974 non-null   int64
#  1   score            9974 non-null   int32
#  2   city             9974 non-null   object
#  3   gender           9974 non-null   object
#  4   age              9974 non-null   int32
#  5   equity           9974 non-null   int64
#  6   balance          7695 non-null   float64
#  7   products         9974 non-null   int64
#  8   credit_card      9974 non-null   int64
#  9   last_activity    9974 non-null   int64
#  10  est_salary       9974 non-null   float64
#  11  churn            9974 non-null   int64
#  12  missing_balance  9974 non-null   int32
#  13  Ростов           9974 non-null   int32
#  14  Рыбинск          9974 non-null   int32
#  15  Ярославль        9974 non-null   int32
#  16  Ж                9974 non-null   int32
# ...

# %% [markdown]
# Вывод: перед нами данные о 10000 клиентах из 3 городов, мужчины и женщины в возрасте от 18 до 86 лет, с баллами
# собственности от 642 до 1000, которые пользуются до 5 продуктами банка. Проведена проверка на наличие дубликатов, пропущенных значений.
# В датафрейме встречаются строки с одинаковыми значениями id клиента. Так как эти пользователи из разных городов, передположим, что присвоение идентификатора пользователя в разных филиалах банка происходит независимо. Оставляем. Заменим пропущенные значения в столбце age на 0. В дальнейшем будем учитывать, что минимальный возраст клиента - 18 лет.
# Наличие пропущенных значений в столбце balance не имеет прямой связи ни с наличием кредитной карты, ни с количеством продуктов, которыми пользуется клиент, ни с приблизительной оценкой собственности клиента. Вероятно, наличие пропусков связано с тем, что данные клиенты не имеют депозитных, накопительных счетов или вкладов и пользуются другими продуктами и услугами банка: кредитные карты, страхование, банковские ячейки и др.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊 <a class="tocSkip"> </h2>
#
# Здорово, что есть промежуточный вывод) Хорошая работа по блоку предобработки)

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# ### Портрет клиента

# %% [markdown]
# Посмотрим моду и медианы по основным характеристикам клиентов банка в разрезе оттока

# %%
df_churn=df.groupby(['churn']).agg({'score':'median','city':pd.Series.mode, 'gender':pd.Series.mode, 'age':['median','mean'], 'equity':pd.Series.mode, 'balance':['median','mean'],'products':pd.Series.mode,'credit_card':[pd.Series.mode,'sum'],'last_activity':[pd.Series.mode,'sum'],'est_salary':['median','mean']}) 
df_churn
# Out:
#        score       city gender    age            equity    balance  \
#       median       mode   mode median       mean   mode     median
# churn
# 0      848.0  Ярославль      Ж   40.0  43.020846      0  475410.09
# 1      866.0  Ярославль      М   39.0  41.450247      5  783908.90
#
#                     products credit_card       last_activity       est_salary  \
#                mean     mode        mode   sum          mode   sum     median
# churn
# 0      7.330316e+05        2           1  5781             0  3938  118227.60
# 1      1.134458e+06        2           1  1003             1  1277  125395.22
#
#
#                 mean
# churn
# 0      147674.637881
# 1      148289.702221

# %% [markdown]
# * Лояльные клиенты: преимущественно женщины, из Ярославля, средний возраст 43 года(медианное значение -40 лет), чаще это клиенты с 0 баллами собственности, пользуются 2 продуктами, есть кредитная карта и были не активны в последнее времяю. имеют с среднем 848 баллов кредитного скоринга, баланс на карте около 475,4 тыс.рублей и доходом 118,2 тыс.руб
# * Отточные клиенты также в основном из Ярославля, преимущественно мужчины, средний возраст 39 лет и имеют баллы кредитного скоринга около 866. Чаще всего у отточных клиентов 5 баллов собственности, они также пользуются 2 продуктами, есть кредитная карта, но были активны в последнее время. Средний доход почти не отличается, а вот баланс на счете сильно отличается, у отточных клиентов на балансе в среднем 1134,5 тыс.рублей (медианное значение- 784 тыс.руб.)

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий тимлида 🤓<a class="tocSkip"> </h2>
#
# Будет хорошо собрать твблицу одной строкой кода, для этого использовать pivot_table, где в качестве столбцав будут churn. Либо churn использовать как значения, и применить функции суммы, подсчета и среднего.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
# <s>
# Подписи в легендах следует скорректировать, заменить текстом 0/1 на отточные/неотточные и т.д.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Этот раздел полностью изменила, решила графики здесь не выводить</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊 v_2<a class="tocSkip"> </h2>
#
# Замечательная работа по сравнению отточного и неотточного клиентов)

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий тимлида 🤓 v_2 <a class="tocSkip"> </h2>
#
# Будет хорошо транспонировать таблицу и указать где отточный и неотточный клиенты)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
# <s>
# Нужно будет сравнить количественные портреты клиентов, т.е. показатели типичных клиентов (как анализ стат.гипотез на равенство средних, только без стат.методов, на глаз). Это значит взять подходящие средние тенденции и посчитать для каждой характеристики, на сколько процентов это число больше (меньше) у отточных по сравнению с неотточными.
#
# Удобнее всего использовать сводную таблицу.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий тимлида 🤓<a class="tocSkip"> </h2>
#
# Как создать через сводную:
#
# ```python
#     = df.groupby(['column']).agg({'column1':'mean', 'column2':pd.Series.mode,
#                                   ...)
# ```

# %% [markdown]
#  ### Анализ отточных клиентов. Распределения

# %% [markdown]
# Распределение баллов кредитного скоринга

# %%
plt.style.use('classic')

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='score', hue='churn', stat="density", common_norm=False, kde=True, bins=50)
plt.grid(True)
plt.title('Распределение баллов кредитного скоринга')
plt.xlabel('баллы скоринга')
plt.ylabel('частота')
plt.legend(['отточные','оставшиеся']) 
plt.show()

# %% [markdown]
# В промежутке от 830 до 910 баллов кредитного скоринга доли отточных клиентов выше, чем оставшихся.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
# <s>
# Так как данные графики мы потом будем использовать в презентации, подписи в легенде нужно сделать текстовыми (т.е. не "0" и "1", а "отток" и "остались" или как тебе удобнее, но текстом) На всех графиках)
#
# Для анализа необходимо использовать нормированные графики, дл этого задать параметры (в декомпозиции есть подсказки).
#
# Будет хорошо увеличить графики.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Эльвира, не нашла, как задать правильно параметры для нормирования графика. </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️ v_2<a class="tocSkip"></h2>
#
# Оставила комментарий ниже. Графики нужно увеличить и нужно будет добавить вывод по каждому графику

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️ v_3<a class="tocSkip"></h2>
#
# В выводах необходимо указатьотрезки, где доля оттока выше неотточных. Их распределение выше будет находится. Например как здесь:
#
# ![image.png](attachment:image.png)
#
#
# Это не всегда пиковые значения будут, а границы, где линии будут пересекаться. Графики все еще нужно увеличить.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий тимлида 🤓 v_2 <a class="tocSkip"> </h2>
#
# По обычным гистограммам или sns.countplot графикам можно делать грубые выводы, но из-за необходимости делать поправки на разные размеры групп в уме, точных выводов по ним обычно не сделаешь. Нивелировать разницы в размерах групп можно если применить <tt>sns.kdeplot</tt> или <tt>sns.hisplot</tt> с параметрами <tt>hue</tt> и настройками <tt>stat="density", common_norm=False</tt> (для kdeplot stat="density" не нужно, common_norm=False нужно именно при использовании hue). При использовании plt.hist и основанных на нём методах pandas достаточно установить параметр <tt>density=True</tt>, также понадобится установить прозрачность (цвета лучше подобрать так, чтобы было меньше затруднений от того, что они смешаются). Обращаю внимание, что метод <tt>sns.dis<b>t</b>plot</tt> является устаревшим и его нежелательно использовать.
#
# В px.histogram, если хочется использовать именно эту библиотеку, можно установить параметры <tt>histnorm='probability density',barmode ='overlay'</tt>. Если категорий больше двух, то для облегчения восприятия можно передать в метод графика параметр <tt>barnorm='percent'</tt> и <tt>barmode='stack'</tt>.
#
# В целом гистограммы подходят для непрерывных переменных и переменных с большим числом уникальных значений. Если гистограмма "идёт лесенкой", это означает, что для дискретной переменной выбрано некратное количество корзин. Можно использовать параметр <tt>binwidth</tt>, но только для дискретных величин, не достигающих огромных значений (может приводить к зависанию ядра). Для анализа бинарных и категориальных признаков гистограммы не подходят.
#
# Для категориальных есть очень простой и действенный, а главное понятный и больше подходящий для презентации подход — можно делать сводные таблицы pivot_table с уровнем оттока по категориям (или сделать группировку по категории с последующей аггрегацией информации об оттоке) и из них столбиковые диаграммы со средним уровнем оттока по банку.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Внесла изменения в графики, спасибо</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊 v_3 <a class="tocSkip"> </h2>
#
# Отличный получился график, молодец)

# %% [markdown]
# Распределение возраста клиентов

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='age', hue='churn', stat="density", common_norm=False, kde=True, bins=50)
plt.grid(True)
plt.title('Распределение возраста клиентов')
plt.xlabel('возраст')
plt.ylabel('частота')
plt.legend(['отточные','оставшиеся']) 
plt.show()

# %% [markdown]
# По графику распределения отточных клиентов по возрасту можно выделить две группы наиболее отточных клиентов по возрасту: от 25 до 35 и от 50 до 60 лет.

# %% [markdown]
# Распределение показателя "оценочный доход клиента"

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='est_salary', hue='churn', stat="density", common_norm=False, kde=True, bins=50)
plt.grid(True)
plt.title('Распределение дохода клиентов')
plt.xlabel('доходы')
plt.ylabel('частота')
plt.legend(['отточные','оставшиеся']) 
plt.show()

# %% [markdown]
# оставим только данные о доходах клиентов до 300000 руб, отбросим выбросы

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df.query('est_salary<300000'), x='est_salary', hue='churn', stat="density", common_norm=False, kde=True, bins=50)
plt.grid(True)
plt.title('Распределение дохода клиентов')
plt.xlabel('доходы')
plt.ylabel('частота')
plt.legend(['отточные','оставшиеся']) 
plt.show()

# %% [markdown]
# Из банка уходят чаще клиенты с более высоким доходом, чем у оставшихся. Доля отточных клиентов выше оставшихся с доходами в промежутке от 100 до 220 тысяч рублей.

# %% [markdown]
# Распределение показателя "баланс"

# %%
sns.histplot(data=df.query('balance<1500000'), x='balance', hue='churn',stat="density", common_norm=False, kde=True, bins=40)
plt.grid(True)
plt.title('Распределение баланса')
plt.xlabel('баланс на счете')
plt.ylabel('частота')
plt.legend(['отточные','оставшиеся']) 
plt.show()

# %% [markdown]
# На графике видно, что доля оттока выше у клиентов с остатками на счете от 800 тыс.

# %% [markdown]
#     В промежутке от 830 до 910 баллов кредитного скоринга доли отточных клиентов выше, чем оставшихся.
#     По графику распределения отточных клиентов по возрасту можно выделить две группы наиболее отточных клиентов по возрасту: от 25 до 35 и от 50 до 60. При этом чаще всего уходят клиенты в возрасте примерно 32-33 лет.
#     Из банка уходят чаще клиенты с более высоким доходом. Доля отточных клиентов выше оставшихся с доходами в промежутке от 100 до 220 тысяч рублей.
#     Доля оттока выше у клиентов с остатками на счете от 800 тыс.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
#
#
# Выводы нужно будет дополнить указать промежутки, где доля оттока будет выше)

# %% [markdown]
#  ### Анализ оттока клиентов. Доли отточных клиентов

# %% [markdown]
# Посчитаем средний процент оттока клиентов по банку

# %%
average_percentage = round(100*df['churn'].mean(),2)
average_percentage
# Out:
# 18.24

# %% [markdown]
# Построим столбчатые диаграммы доли отточных клиентов по параметрам 'city','gender', 'equity', 'products', 'credit_card', 'last_activity'

# %%
parameters=['city','gender', 'equity', 'products', 'credit_card', 'last_activity']

for i in range(len(parameters)):
    data= pd.pivot_table(df, index=parameters[i], columns='churn', values='user_id', aggfunc='count').reset_index()
    data.columns=[i, 'loyal', 'churn']
    data['percent_churn']=round(100*data['churn']/(data['churn']+data['loyal']),2)
    print(data)
    print('средний процент оттока клиентов по банку',average_percentage)
    ax = sns.barplot(x=i, y='percent_churn', data=data) 
    plt.title(f'Доля отточных клиентов по {parameters[i]}')
    plt.ylabel('Процент оттока')
    plt.xlabel(f'параметр {parameters[i]}')
    plt.axhline(average_percentage, color='r', linestyle='--')
    plt.show()
# Out:
#            0  loyal  churn  percent_churn
# 0     Ростов   1151    265          18.71
# 1    Рыбинск   2246    437          16.29
# 2  Ярославль   4758   1117          19.01
# средний процент оттока клиентов по банку 18.24
#    1  loyal  churn  percent_churn
# 0  Ж   4347    636          12.76
# 1  М   3808   1183          23.70
# средний процент оттока клиентов по банку 18.24
#    2  loyal  churn  percent_churn
# 0  0   2486     90           3.49
# 1  1    680     93          12.03
# 2  2    885    166          15.79
# 3  3   1219    322          20.90
# 4  4   1383    464          25.12
# 5  5   1339    576          30.08
# 6  6    103     58          36.02
# 7  7     43     37          46.25
# 8  8     11      6          35.29
# 9  9      6      7          53.85
# средний процент оттока клиентов по банку 18.24
#    3   loyal  churn  percent_churn
# 0  0     NaN    1.0            NaN
# 1  1  3088.0  235.0           7.07
# 2  2  4141.0  978.0          19.11
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
# <s>
#
# Некоторые блоки кода не работают. Посмотри, пожалуйста, что пошло не так. Перед отправкой проекта стоит проверять работоспособность кода — это можно сделать, нажав на панели Jupiter Hub ``Kernel`` и ``Restart & Run All`` (см скриншот ниже).
# ![](https://i.postimg.cc/yd19rYf6/Screenshot-428.png)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>Что то пошло не так.. странно, но у меня запустился без проблем. Возьму на заметку, что лучше перепроверить. Спасибо</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊  v_2 <a class="tocSkip"> </h2>
#
# Отлично)

# %% [markdown]
#     Доля оттока клиентов в Ярославле (18,97) и Ростове (18,77) немного превышает средний процент оттока клиентов по банку, -18,2%.
#     Процент оттока у мужчин выше среднего значения _ 23,64%.
#     Самый высокий процент оттока - 53,85% - у клиентов с 9 баллами собстенности. Однако с учетом количества клиентов по данной категории и среднего процента оттока по банку, следует расмотреть выборки клиентов с 3, 4 и 5 баллами собственности.
#     Доля отточных клиентов, которые пользуются двумя и более продуктами банка, выше среднего процента оттока клиентов.
#     Клиенты, которые не пользуются кредитными картами, чаще становятся "отточными", 25,56% таких клиентов намереваются уйти из банка.
#     Интересно отметить, что активные в последнее время клиенты чаще принимают решение уйти из банка, процент оттока активных клиентов -24,41%.

# %% [markdown]
# ### Корреляционный анализ

# %%
df_corr=df.corr()
df_corr=df_corr.drop(['user_id','missing_balance'])
df_corr
# Out:
#                 user_id     score       age    equity   balance  products  \
# score          0.008778  1.000000 -0.011814  0.064809  0.235283 -0.004071
# age            0.017795 -0.011814  1.000000  0.020628  0.069745  0.017182
# equity         0.005837  0.064809  0.020628  1.000000  0.163793  0.430945
# balance        0.005479  0.235283  0.069745  0.163793  1.000000  0.075716
# products      -0.003175 -0.004071  0.017182  0.430945  0.075716  1.000000
# credit_card    0.005001 -0.095261 -0.123128 -0.167271 -0.059850 -0.251120
# last_activity -0.032022 -0.030343 -0.008157 -0.002011  0.024770  0.037555
# est_salary    -0.001103  0.164166 -0.039598 -0.171515  0.338800 -0.117556
# churn         -0.010865  0.106404 -0.049797  0.270084  0.085915  0.300621
# Ростов        -0.032729 -0.037573  0.046985  0.035364 -0.035635 -0.006884
# Рыбинск        0.013567 -0.000789  0.029453 -0.004973 -0.034420 -0.042255
# Ярославль      0.010990  0.027365 -0.059876 -0.020604  0.056967  0.042967
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
#
# Номер пользователя в таблице корреляции не отображаем здесь и ниже.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> исправила.</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️ v_2 <a class="tocSkip"></h2>
#
# Еще отображается ниже и столбец с пропущенными значениями в балансе тоже нужно опустить и не отображать, так как его изучили ранее)

# %% [markdown]
# Для оценки корреляции воспользуемся шкалой Чеддока:
# ![%D1%88%D0%BA%D0%B0%D0%BB%D0%B0%20%D0%A7%D0%B5%D0%B4%D0%B4%D0%BE%D0%BA%D0%B0.png](attachment:%D1%88%D0%BA%D0%B0%D0%BB%D0%B0%20%D0%A7%D0%B5%D0%B4%D0%B4%D0%BE%D0%BA%D0%B0.png)

# %%
plt.figure(figsize = (15, 6))
sns.heatmap(df_corr, annot=True, cmap='coolwarm', center=0, fmt='.2%')    
plt.title('Тепловая карта удержания') 
plt.show()

# %%
sns.heatmap(df_corr.loc[:,['churn']].drop('churn').sort_values('churn'), annot=True, cmap='vlag', center=0, fmt='.2%')    
plt.title('Корреляция оттока') 
plt.show()

# %% [markdown]
# По матрице корреляции отметим наличие слабой зависимости оттока клиентов от количества продуктов. По остальным характеристикам зависимость очень слабая.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊<a class="tocSkip"> </h2>
#
# Здорово, что отображаешь только интересующий нас столбец и есть пояснение!)

# %% [markdown]
# ## Статистический анализ

# %% [markdown]
# ### Гипотеза различия дохода между теми клиентами, которые ушли и теми, которые остались

# %% [markdown]
# Cоздадим два датафрейма с отточными клиентами и оставшимися

# %%
churn = df.query('churn == 1')
loyalty = df.query('churn == 0')

# %%
# посчитаем дисперсию и средние значения доходов клиентов 
var_churn = np.array(churn['est_salary'])
var_loyalty = np.array(loyalty['est_salary'])

print('Дисперсия зарплат оставшихся клиентов:', np.var(var_loyalty))
print('Дисперсия зарплат ушедших клиетов:', np.var(var_churn))
print()
print('Средняя зарплата оставшихся клиентов:', np.mean(var_loyalty))
print('Средняя зарплата ушедших клиетов:', np.mean(var_churn))
# Out:
# Дисперсия зарплат оставшихся клиентов: 20356342952.421223
# Дисперсия зарплат ушедших клиетов: 15104008500.895664
#
# Средняя зарплата оставшихся клиентов: 147674.63788105457
# Средняя зарплата ушедших клиетов: 148289.70222100057

# %% [markdown]
# Проверим гипотезу о том, что выборка взята из нормально распределённой генеральной совокупности. Воспользуемся критерием Шапиро-Уилка.

# %%
sample=np.array(df['est_salary'])

alpha = 0.05
results = shapiro(sample)
p_value = results[1]

results1=kstest(sample, 'norm')

print('p-значение: ', p_value)

if p_value < alpha:
    print('Отвергаем нулевую гипотезу: распределение не нормально')
    
else:
     print('Не получилось отвергнуть нулевую гипотезу, всё нормально')
# Out:
# p-значение:  0.0
# Отвергаем нулевую гипотезу: распределение не нормально

# %% [markdown]
# Сформулируем нулевую и альтернативную гипотезы:
#
# * Н0: средний доход отточных и лояльных клиентов равны.
# * Н1: средний доход отточных и лояльных клиентов не равны.

# %%
sample_1=loyalty['est_salary']
sample_2=churn['est_salary']

alpha = 0.05 # уровень статистической значимости
# если p-value окажется меньше него, отвергнем гипотезу

results = st.ttest_ind(sample_1, sample_2,equal_var=False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.8515799588935961
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Проведенный t-test показал, что опровергнуть гипотезу о различии среднего дохода между клиентами, которые ушли и теми, которые остались, не удалось.

# %% [markdown]
# Воспользуемся U-критерием Манна-Уитни для проверки гипотезы

# %%
results = st.mannwhitneyu(sample_1, sample_2)

print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя')
# Out:
# p-значение:  0.0001941125216825749
# Отвергаем нулевую гипотезу: разница статистически значима

# %% [markdown]
# ttest и utest показали разные результаты. Так как распределение ненормальное и дисперсии не равны, будем ориентироваться на utest. Нулевую гипотезу отвергаем, средний доход отточных и лояльных клиентов не равны.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊<a class="tocSkip"> </h2>
#
# Гипотезы составлены верно и тест проведен правильно

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️ v_3 <a class="tocSkip"></h2>
#
# Смотри, а как мы определили, что распределение нормальное? Разве совсем нет выбросов ? Нужно доработать, не могу согласиться с выбранным тестом по аргументам.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️ v_2 <a class="tocSkip"></h2>
#
# Давай укажем критерии к t-тесту и проверим удовлетворяют ли данные им)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
#
# Первую гипотезу, о том, влияет ли отток на доходы клиентов, необходимо проверить и t-критерием и u-критерием, объяснить расхождения, если они возникнут, выбрать, какому критерию стоит доверять сильнее. Т.к. необходимо понимать, когда следует применять t-критерий Стьюдента, а когда u-критерий Манна-Уитни, стоит описать, из-за чего между результатами работы критериев могут возникать расхождения, даже если они не возникли в данном случае.

# %% [markdown]
# ### Гипотеза различия количества банковских продуктов между теми клиентами, которые ушли и теми, которые остались

# %% [markdown]
# Сформулируем нулевую и альтернативную гипотезы:
#
# * Н0: среднее количество банковских продуктов у отточных и лояльных клиентов равны.
# * Н1: среднее количество банковских продуктов у отточных и лояльных клиентов не равны.

# %%
sample_1=loyalty['products']
sample_2=churn['products']

alpha = 0.05 # уровень статистической значимости
# если p-value окажется меньше него, отвергнем гипотезу

results = st.ttest_ind(sample_1, sample_2,equal_var=False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 7.537464337201273e-138
# Отвергаем нулевую гипотезу

# %% [markdown]
# Проведенный t-test показал, что нулевую гипотезу о различии среднего количества банковских продуктов у отточных и лояльных клиентов сдедует отвергнуть. Что подтверждает результаты исследовательского анализа.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊<a class="tocSkip"> </h2>
#
# Верно)

# %% [markdown]
# ### Гипотеза различия количества баллов собственности между теми клиентами, которые ушли и теми, которые остались

# %% [markdown]
# Сформулируем нулевую и альтернативную гипотезы:
#
# * Н0: среднее количество баллов собственности у отточных и лояльных клиентов равны.
# * Н1: среднее количество баллов собственности у отточных и лояльных клиентов не равны.

# %%
sample_1=loyalty['equity']
sample_2=churn['equity']

alpha = 0.05 # уровень статистической значимости
# если p-value окажется меньше него, отвергнем гипотезу

results = st.ttest_ind(sample_1, sample_2,equal_var=False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 2.0104399828205813e-196
# Отвергаем нулевую гипотезу

# %% [markdown]
# Проведенный t-test показал, что нулевую гипотезу о различии среднего количества баллов собственности у отточных и лояльных клиентов следует отвергнуть. Что подтверждает результаты исследовательского анализа.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊<a class="tocSkip"> </h2>
#
# Статистические тесты проведены верно)

# %% [markdown]
# ## Сегментация

# %%
df.head()
# Out:
#    user_id  score       city gender  age  equity     balance  products  \
# 0   183012    850    Рыбинск      Ж   25       1    59214.82         2
# 1   146556    861    Рыбинск      Ж   37       5   850594.33         3
# 2   120722    892    Рыбинск      Ж   30       0         NaN         1
# 3   225363    866  Ярославль      Ж   51       5  1524746.26         2
# 4   157978    730  Ярославль      М   34       5      174.00         1
#
#    credit_card  last_activity  est_salary  churn  missing_balance  Ростов  \
# 0            0              1    75719.14      1                0       0
# 1            1              0    86621.77      0                0       0
# 2            1              1   107683.34      0                1       0
# 3            0              1   174423.53      1                0       0
# 4            1              0    67353.16      1                0       0
#
#    Рыбинск  Ярославль  Ж  М
# 0        1          0  1  0
# 1        1          0  1  0
# ...

# %% [markdown]
# Сегмент 1.
# Клиенты, которые не пользуются кредитной картой, были активны в последнее время и имеют доход от 100 до 220 тысяч

# %%
df_1 = df.query('credit_card==0 and 100000<est_salary<220000 and last_activity==1').agg({'churn': ['mean','sum','count']})
df_1
# Out:
#             churn
# mean     0.413793
# sum    336.000000
# count  812.000000

# %% [markdown]
# Процент оттока выше среднего(49.5%), количество потенциально отточных клиентов -244

# %% [markdown]
# Сегмент 2.
# Мужчины с баллами кредитного скоринга от 800 до 910, с более 5 баллами собственности

# %%
df_2 = df.query('М==1 and 800<=score<=910 and equity>=5').agg({'churn': ['mean','sum','count']})
df_2
# Out:
#             churn
# mean     0.408917
# sum    321.000000
# count  785.000000

# %% [markdown]
# Процент оттока выше среднего (40,9%), количество отточных клиентов - 321

# %% [markdown]
# Сегмент 3.
# клиенты которые имеют более 2 объектов собственности, пользуются более чем двумя продуктами и баланс на счете более 800тыс.руб

# %%
df_3 = df.query('equity>2 and balance>800000 and products>2').agg({'churn': ['mean','sum','count']})
df_3
# Out:
#             churn
# mean     0.546875
# sum    350.000000
# count  640.000000

# %% [markdown]
# Процент оттока выше среднего (54,7%), количество отточных клиентов - 350

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий тимлида 😊<a class="tocSkip"> </h2>
#
# Нашли два отточных сегмента, хорошая работа)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️ v_3 <a class="tocSkip"></h2>
#
# Нужно будет скорректировать, на определенные в исследовательском анализе)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
# <s>
# Но остальные три не подходят нашим критериям.
#
# Нам нужно 3 одновременно крупных (>300 и <2000 клиентов)  и отточных (уровень оттока минимум в 2 раза выше среднего по банку) и при этом разнообразных по признакам (чтобы уменьшить пересечение клиентов между выбранными сегментами). Только так мы сможем предложить разные меры для удержания клиентов.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️ v_2 <a class="tocSkip"></h2>
# <s>
# Средний уровень оттока по банку 18, нам нужно найти сегменты с оттоком не менее 36%

# %% [markdown]
# ## Вывод
#
#     В результате проведенного анализа определили параметры, влияющие на отток:
# - чем выше оценка собственности, тем больше процент отточных клиентов;
# - клиенты с более высоким скоринговым рейтингом показывают более высокий процент оттока;
# - отсутствие у клиента кредитной карты сильно повышает риск его оттока из банка;
# - активные клиенты покидали банк чаще, чем менее активные;
# - мужчины намного сильнее склонны уходить из банка, чем женщины;
# - наиболее отточные возрастные группы - 25-35 и 50-60
#
#    Был проведен статистический анализ следующих гипотез:
#
# Гипотеза №1 о различии доходов оставшихся и отточных клиентов: подтвердилась
# Гипотеза №2 о различии в количестве используемых банковских продуктов оставшихся и отточных клиентов: подтвердилась
# Гипотеза №3 о различии  количества баллов собственности оставшихся и отточных клиентов: подтвердилась
#
#     Были выделены и приоритизированы сегменты, в наибольшей степени подверженных оттоку (от 41 до 55% отточных клиентов)
#
# Рекомендации:
# 1. По сегменту 1 - Клиенты, которые не пользуются кредитной картой, были активны в последнее время и имеют доход от 100 до 220 тысяч. Почему бы не предложить им новый продукт, кредитную карту например.
# 2. по сегменту 2 Мужчины с баллами кредитного скоринга от 800 до 930, с 5 баллами собственности- это мужчины с хорошей кредитной историей, имеющие несколько объектов собственности. Вероятно, с такими баллами собственности неплохо было бы эту собственность застраховать
# 3. По сегменту 3 - клиенты которые имеют более 2 объектов собственности, пользуются более чем двумя продуктами и баланс на счете более 800тыс.руб. Возможно, повышение процентной ставки по вкладам или начисление кэшбэка за покупки позволит сократить отток данного сегмента.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий тимлида ⛔️<a class="tocSkip"></h2>
# <s>
# Нужно доработать общий вывод добавить все полученные результаты, указать портреты отточного и лояльного, признаки оттока.
#
# Рекомендации должны относиться к конкретному сегменту, имеющему какой-то общий размер и уровень оттока (быть таргетированными), учитывать особенности этого сегмента, быть конкретными (содержать описание каких-то конкретных действий: акций, мероприятий, новых продуктов или изменения старых и т.п.) а не содержать указания для отдела маркетинга кого-то опросить и провести исследование и т.п.

# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <h2> Общий комментарий тимлида 😊 v_3 <a class="tocSkip"> </h2>
#     <br/>
#
# Осталось совсем немного, буду ждать презентацию в следующем ревью)

# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <h2> Общий комментарий тимлида 😊 v_2 <a class="tocSkip"> </h2>
#     <br/>
#
# Проект нуждается в доработке)

# %% [markdown]
# <div style="border:solid Purple 2px; padding: 40px">
#
# <h2> Общий комментарий тимлида 😊<a class="tocSkip"> </h2>
#     <br/>
#  Любовь, хорошая работа по проекту, отлично справился с  корреляционным анализом и статистическими тестами)  Но есть несколько важных моментов, которые необходимо доработать:
#
# * Анализ пропусков;
# * Скорректировать легенды;
# * Неработающие ячейки кода;
# * Сегментация;
# * Остальные комментарии ты найдешь в работе
